# %%
import streamlit as st
import pickle
import pandas as pd

st.set_page_config(page_title="Telco Survival & CLV Dashboard", layout="wide")

st.title("📊 Hệ Thống Dự Báo Sinh Tồn & Giá Trị Vòng Đời Khách Hàng")
st.subheader("Định vị: Phân tích Thống kê Chuyên sâu")

# Kiểm tra xem app có load được model đã lưu ở bước trước không
try:
    with open('cph_tv_model.pkl', 'rb') as f:
        model = pickle.load(f)
    st.success("✅ Kết nối thành công với Mô hình Cox PH (Time-Interaction)!")
except FileNotFoundError:
    st.error("❌ Không tìm thấy file cph_tv_model.pkl. Hãy chắc chắn bạn đã lưu file model vào đúng thư mục app/")
# Out:
# 2026-06-22 21:43:56.322 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 21:43:56.324 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 21:43:58.257
# ...
#   command:
#
#     streamlit run C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-22 21:43:58.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 21:43:58.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 21:43:58.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
